# %%
import hexathello.aiPlayers as aiPlayers
import hexathello.AutoPlayer as autoPlayer
import hexathello.Engine as engine
import hexathello.history as history
import hexathello.jable as jable
import hexathello.printing as printing

import numpy as np

from os import path
import os
import math
import tensorflow as tf

from os import listdir
from os.path import join, isfile


# -- Settings
game_size: int = 5
player_count: int = 2

# %%
matchup_dir = "data/history/matchups_final"

# update with new JSON file
matchup_files = [f for f in listdir(matchup_dir) if f.endswith("final.json")]
print(matchup_files)

agent_ids = [
    "1x720_total720_size5_players2_final",
    "2x360_total720_size5_players2_final",
    "3x240_total720_size5_players2_final",
    "4x180_total720_size5_players2_final",
    "5x144_total720_size5_players2_final",
    "6x120_total720_size5_players2_final",
    "7x102_total714_size5_players2_final"
]
# Out:
# ['all_data_final.json']

# %%
for ai_id in agent_ids:
    print(f"\n Retraining agent: {ai_id}")

    training_pov = []

    relevant_files = [f for f in matchup_files if ai_id in f]

    match_frames = []
    for fname in matchup_files:
        full_path = join(matchup_dir, fname)
        
        history_fromDisk: jable.JyFrame = jable.read_file(
            full_path
        )
    
        history_decoded: jable.JyFrame = history.history_fromInt(
            history_fromDisk
        )
    
        if len(history_decoded) < 20:
            print('skipping')
            continue
    
    
        povHistory: jable.JyFrame = history.povHistory_from_literalHistory(
            history_decoded
        )

        del history_decoded
        del history_fromDisk

        match_frames.append(povHistory)


        input_size: int = len(povHistory[0, 'board_state'])
        output_size: int = len(povHistory[0, 'player_action'])

    keras_path = join("data", "ai", "vary_dimensions", f"{ai_id}.keras")
    if not path.isfile(keras_path):
        print(f"Model not found at {keras_path}")
        continue

    brain_model = tf.keras.models.load_model(keras_path)
    os.makedirs(os.path.dirname(keras_path), exist_ok=True)

    ai_agent = aiPlayers.KerasHexAgent(
        size=game_size,
        player_count=player_count,
        brain=brain_model,
        player_id=None,
        ai_id=ai_id
    )

    checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(
        filepath=keras_path,
        monitor='loss',
        mode='min',
        save_best_only=True
    )

    training_pov_frame: jable.JyFrame = jable.JyFrame(training_pov)

    for povHistory in match_frames:
        ai_agent.train(
            game_history=povHistory,
            epochs=10,
            callbacks=[checkpoint_cb]
        )

    print(f"Retrained and saved model as {keras_path}")
# Out:
#  Retraining agent: 1x720_total720_size5_players2_final
# Epoch 1/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 1.3628
# Epoch 2/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 1.0300
# Epoch 3/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.9570
# Epoch 4/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.9212
# Epoch 5/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.8978
# Epoch 6/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.8793
# Epoch 7/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.8679
# Epoch 8/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.8500
# Epoch 9/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.8398
# Epoch 10/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.8399
# Retrained and saved model as data\ai\vary_dimensions\1x720_total720_size5_players2_final.keras
#
#  Retraining agent: 2x360_total720_size5_players2_final
# Epoch 1/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 1.3561
# Epoch 2/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 1.0770
# Epoch 3/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.9944
# Epoch 4/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.9494
# Epoch 5/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.9255
# Epoch 6/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.9165
# Epoch 7/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.8997
# Epoch 8/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.8958
# Epoch 9/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.8865
# Epoch 10/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.8869
# Retrained and saved model as data\ai\vary_dimensions\2x360_total720_size5_players2_final.keras
#
#  Retraining agent: 3x240_total720_size5_players2_final
# Epoch 1/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 1.4591
# Epoch 2/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 1.2471
# Epoch 3/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 1.1835
# Epoch 4/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 1.1189
# Epoch 5/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 1.0893
# Epoch 6/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 1.0665
# Epoch 7/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 1.0929
# Epoch 8/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 1.0480
# Epoch 9/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 1.0485
# Epoch 10/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 1.0414
# Retrained and saved model as data\ai\vary_dimensions\3x240_total720_size5_players2_final.keras
#
#  Retraining agent: 4x180_total720_size5_players2_final
# Epoch 1/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 1.3629
# Epoch 2/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 1.2622
# Epoch 3/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 1.2203
# Epoch 4/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 1.2017
# Epoch 5/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 1.1890
# Epoch 6/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 1.1716
# Epoch 7/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 1.1690
# Epoch 8/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 1.1630
# Epoch 9/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 1.1535
# Epoch 10/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 1.1561
# Retrained and saved model as data\ai\vary_dimensions\4x180_total720_size5_players2_final.keras
#
#  Retraining agent: 5x144_total720_size5_players2_final
# Epoch 1/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 1.4268
# Epoch 2/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 1.3537
# Epoch 3/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 1.3360
# Epoch 4/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 1.3193
# Epoch 5/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 1.3069
# Epoch 6/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 1.2831
# Epoch 7/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 1.2785
# Epoch 8/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 1.2614
# Epoch 9/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 1.2469
# Epoch 10/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 1.2400
# Retrained and saved model as data\ai\vary_dimensions\5x144_total720_size5_players2_final.keras
#
#  Retraining agent: 6x120_total720_size5_players2_final
# Epoch 1/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 1.4245
# Epoch 2/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 1.3924
# Epoch 3/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 1.3569
# Epoch 4/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 1.3569
# Epoch 5/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 1.3352
# Epoch 6/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 1.3312
# Epoch 7/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 1.3216
# Epoch 8/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 1.3108
# Epoch 9/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 1.3059
# Epoch 10/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 1.2941
# Retrained and saved model as data\ai\vary_dimensions\6x120_total720_size5_players2_final.keras
#
#  Retraining agent: 7x102_total714_size5_players2_final
# Epoch 1/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 1.5061
# Epoch 2/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 1.5084
# Epoch 3/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 1.5269
# Epoch 4/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 1.4962
# Epoch 5/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 1.4929
# Epoch 6/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 1.4980
# Epoch 7/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 1.4932
# Epoch 8/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 1.5160
# Epoch 9/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 1.5041
# Epoch 10/10
# 3906/3906 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 1.5099
# Retrained and saved model as data\ai\vary_dimensions\7x102_total714_size5_players2_final.keras
