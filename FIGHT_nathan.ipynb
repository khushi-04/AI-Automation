# %%
import hexathello.aiPlayers as aiPlayers
import hexathello.AutoPlayer as autoPlayer
import hexathello.Engine as engine
import hexathello.history as history
import hexathello.jable as jable
import hexathello.printing as printing
import numpy as np
from os import path
from tensorflow.keras.models import load_model
import itertools
import os
import math
from tqdm import tqdm

game_size: int = 5
player_count: int = 2
model_paths = {}

brain_models = []



for i in range(9):
    num_layers = i + 1
    neurons_per_layer = 122
    total_neurons = num_layers * neurons_per_layer

    model_name = "kha_layers_{}.keras".format(
        num_layers
    )
    full_path = path.join("data", "ai", "layer_sweeper", model_name)
    model_paths[f"path_to_model_{i}"] = full_path
    model = load_model(model_paths[f"path_to_model_{i}"])
    brain_models.append(model)    
    


ai_keras_0 = aiPlayers.KerasHexAgent(
    size=game_size,
    player_count=player_count,
    brain=brain_models[0],
    ai_id="kha_layers_1", 
    p_random = 0.3
)

ai_keras_1 = aiPlayers.KerasHexAgent(
    size=game_size,
    player_count=player_count,
    brain=brain_models[1],
    ai_id="kha_layers_2", 
    p_random = 0.3
)


ai_keras_2 = aiPlayers.KerasHexAgent(
    size=game_size,
    player_count=player_count,
    brain=brain_models[2],
    ai_id="kha_layers_3", 
    p_random = 0.3
)

ai_keras_3 = aiPlayers.KerasHexAgent(
    size=game_size,
    player_count=player_count,
    brain=brain_models[3],
    ai_id="kha_layers_4", 
    p_random = 0.3
)


ai_keras_4 = aiPlayers.KerasHexAgent(
    size=game_size,
    player_count=player_count,
    brain=brain_models[4],
    ai_id="kha_layers_5", 
    p_random = 0.3
)

ai_keras_5 = aiPlayers.KerasHexAgent(
    size=game_size,
    player_count=player_count,
    brain=brain_models[5],
    ai_id="kha_layers_6", 
    p_random = 0.3
)


ai_keras_6 = aiPlayers.KerasHexAgent(
    size=game_size,
    player_count=player_count,
    brain=brain_models[6],
    ai_id="kha_layers_7", 
    p_random = 0.3
)

ai_keras_7 = aiPlayers.KerasHexAgent(
    size=game_size,
    player_count=player_count,
    brain=brain_models[7],
    ai_id="kha_layers_8", 
    p_random = 0.3
)

ai_keras_8 = aiPlayers.KerasHexAgent(
    size=game_size,
    player_count=player_count,
    brain=brain_models[8],
    ai_id="kha_layers_9", 
    p_random = 0.3
)

# %%
agents_list = [ai_keras_0, ai_keras_1, ai_keras_2, ai_keras_3, ai_keras_4, ai_keras_5, ai_keras_6, ai_keras_7, ai_keras_8]

# get elo of each agent in order and update accordingly
current_elo = [4000]*9

# many many games per combo-- let's do this
num_games = 1000

pairs = list(itertools.combinations(agents_list, 2))
total_games = len(pairs) * num_games
pbar = tqdm(total=total_games, desc="Games played")


for agent_i, agent_j in itertools.combinations(agents_list, 2):
    index_i = agents_list.index(agent_i)
    index_j = agents_list.index(agent_j)
    print(f"Running match: {agent_i.ai_id} vs {agent_j.ai_id}")
    agent_i.player_id = 0
    agent_j.player_id = 1
    for runs in range(num_games):
        literalHistory = autoPlayer.runHexathello_withAgents(
            agents=[agent_i, agent_j],
            size=game_size,
            logging_level=0
        )
        if literalHistory._fixed["winner"] == 0:
            winner = index_i
            loser = index_j
            draw = False
        if literalHistory._fixed["winner"] == 1: 
            winner = index_j
            loser = index_i
            draw = False
        if literalHistory._fixed["winner"] == None:
            winner = index_i
            loser = index_j
            draw = True

        current_rating_winner = current_elo[winner]
        current_rating_loser = current_elo[loser]
    
        expected_winner = 1 / (1 + 10 ** ((current_rating_loser - current_rating_winner) / 400))
        expected_loser = 1 / (1 + 10 ** ((current_rating_winner - current_rating_loser) / 400))
        if not draw: 
            current_elo[winner] = current_elo[winner] + (50*(1-expected_winner))
            current_elo[loser] = current_elo[loser] + (50*(0-expected_loser))
        else:
            current_elo[winner] = current_elo[winner] + (50*(0.5-expected_winner))
            current_elo[loser] = current_elo[loser] + (50*(0.5-expected_loser))
        pbar.update(1)
            
pbar.close()

print(f"final elos: {current_elo}")
# Out:
# Games played:   0%|                                                                                          | 0/36 [00:00<?, ?it/s]
# Running match: kha_layers_1 vs kha_layers_2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Games played:   3%|██▎                                                                               | 1/36 [00:01<00:58,  1.67s/it]
# Early end, no move for any player
# RESULT: 16 - 26; Player 1 wins
# # Game done
# {'winner': 1, 'turn_index': 36, 'size': 5, 'game_complete': True, 'empty_count': 19, 'player_count': 2, 'current_player': 1, 'scores': [16, 26]}
# Running match: kha_layers_1 vs kha_layers_3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Games played:   6%|████▌                                                                             | 2/36 [00:03<00:54,  1.59s/it]
# Early end, no move for any player
# RESULT: 16 - 26; Player 1 wins
# # Game done
# {'winner': 1, 'turn_index': 36, 'size': 5, 'game_complete': True, 'empty_count': 19, 'player_count': 2, 'current_player': 1, 'scores': [16, 26]}
# Running match: kha_layers_1 vs kha_layers_4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Early end, no move for any player
# Games played:   8%|██████▊                                                                           | 3/36 [00:04<00:51,  1.56s/it]
# RESULT: 31 - 11; Player 0 wins
# # Game done
# {'winner': 0, 'turn_index': 36, 'size': 5, 'game_complete': True, 'empty_count': 19, 'player_count': 2, 'current_player': 0, 'scores': [31, 11]}
# Running match: kha_layers_1 vs kha_layers_5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Games played:  11%|█████████                                                                         | 4/36 [00:06<00:51,  1.59s/it]
# Early end, no move for any player
# RESULT: 16 - 26; Player 1 wins
# # Game done
# {'winner': 1, 'turn_index': 36, 'size': 5, 'game_complete': True, 'empty_count': 19, 'player_count': 2, 'current_player': 0, 'scores': [16, 26]}
# Running match: kha_layers_1 vs kha_layers_6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Games played:  14%|███████████▍                                                                      | 5/36 [00:08<00:50,  1.62s/it]
# Early end, no move for any player
# RESULT: 7 - 34; Player 1 wins
# # Game done
# {'winner': 1, 'turn_index': 35, 'size': 5, 'game_complete': True, 'empty_count': 20, 'player_count': 2, 'current_player': 1, 'scores': [7, 34]}
# Running match: kha_layers_1 vs kha_layers_7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Games played:  17%|█████████████▋                                                                    | 6/36 [00:09<00:50,  1.68s/it]
# Early end, no move for any player
# RESULT: 15 - 27; Player 1 wins
# # Game done
# {'winner': 1, 'turn_index': 36, 'size': 5, 'game_complete': True, 'empty_count': 19, 'player_count': 2, 'current_player': 0, 'scores': [15, 27]}
# Running match: kha_layers_1 vs kha_layers_8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Games played:  19%|███████████████▉                                                                  | 7/36 [00:11<00:46,  1.60s/it]
# Early end, no move for any player
# RESULT: 30 - 12; Player 0 wins
# # Game done
# {'winner': 0, 'turn_index': 36, 'size': 5, 'game_complete': True, 'empty_count': 19, 'player_count': 2, 'current_player': 0, 'scores': [30, 12]}
# Running match: kha_layers_1 vs kha_layers_9
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Games played:  22%|██████████████████▏                                                               | 8/36 [00:12<00:40,  1.46s/it]
# Early end, no move for any player
# RESULT: 28 - 14; Player 0 wins
# # Game done
# {'winner': 0, 'turn_index': 36, 'size': 5, 'game_complete': True, 'empty_count': 19, 'player_count': 2, 'current_player': 1, 'scores': [28, 14]}
# Running match: kha_layers_2 vs kha_layers_3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Games played:  25%|████████████████████▌                                                             | 9/36 [00:13<00:39,  1.45s/it]
# Early end, no move for any player
# RESULT: 18 - 24; Player 1 wins
# # Game done
# {'winner': 1, 'turn_index': 36, 'size': 5, 'game_complete': True, 'empty_count': 19, 'player_count': 2, 'current_player': 0, 'scores': [18, 24]}
# Running match: kha_layers_2 vs kha_layers_4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Games played:  28%|██████████████████████▌                                                          | 10/36 [00:15<00:37,  1.44s/it]
# Early end, no move for any player
# RESULT: 9 - 33; Player 1 wins
# # Game done
# {'winner': 1, 'turn_index': 36, 'size': 5, 'game_complete': True, 'empty_count': 19, 'player_count': 2, 'current_player': 1, 'scores': [9, 33]}
# Running match: kha_layers_2 vs kha_layers_5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Games played:  31%|████████████████████████▊                                                        | 11/36 [00:16<00:37,  1.50s/it]
# Early end, no move for any player
# RESULT: 15 - 27; Player 1 wins
# # Game done
# {'winner': 1, 'turn_index': 36, 'size': 5, 'game_complete': True, 'empty_count': 19, 'player_count': 2, 'current_player': 1, 'scores': [15, 27]}
# Running match: kha_layers_2 vs kha_layers_6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Games played:  33%|███████████████████████████                                                      | 12/36 [00:18<00:38,  1.60s/it]
# Early end, no move for any player
# RESULT: 27 - 15; Player 0 wins
# # Game done
# {'winner': 0, 'turn_index': 36, 'size': 5, 'game_complete': True, 'empty_count': 19, 'player_count': 2, 'current_player': 1, 'scores': [27, 15]}
# Running match: kha_layers_2 vs kha_layers_7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 21
#      19 agent_j.player_id = 1
#      20 for runs in range(num_games):
# ---> 21     literalHistory = autoPlayer.runHexathello_withAgents(
#      22         agents=[agent_i, agent_j],
#      23         size=game_size,
#      24         logging_level=0
#      25     )
#      26     if literalHistory._fixed["winner"] == 0:
#      27         winner = index_i
#
# File ~\Documents\StatUS\hexathello\AutoPlayer.py:159, in runHexathello_withAgents(agents, size, logging_level, rng, hexagonGridHelper)
#     152     action_choices[
#     153         hexagonGridHelper.index_from_qr_tuple( qr )
#     154     ] = 1.0
#     155 #/for qr in moves
#     157 next_move: engine.PlayerMove = agents[
#     158     next_player_index
# --> 159 ].getMove_fromBoardState(
#     160     boardState = hexathello.boardState,
#     161     turn_index = turn_index,
#     162     rng = rng,
#     163     potential_moves = hexathello.potential_moves
#     164 )
#     166 next_qr = ( next_move["q"], next_move["r"] )
#     168 if next_qr in move_log:
#
# File ~\Documents\StatUS\hexathello\aiPlayers.py:258, in KerasHexAgent.getMove_fromBoardState(self, boardState, turn_index, rng, potential_moves)
#     250 boardState_vector: np.ndarray = self.getBoardState_asRelativeStateVector(
#     251     boardState
#     252 )
#     254 # Use our brain to get weighs of each move
#     255 # NOTE: We can choose from these weights using
#     256 #   self.chooseMove(...), something like the max
# --> 258 moveChoice_vector: np.ndarray = self.brain.predict(
#     259     np.reshape(
#     260         boardState_vector,
#     261         newshape = (1, len( boardState_vector ) )
#     262     )
#     263 )
#     265 # Mask it with legal moves
#     267 assert len( moveChoiceDict ) > 0
#
# File ~\anaconda3\envs\smartenv\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\smartenv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:559, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     557 for step, iterator in epoch_iterator:
#     558     callbacks.on_predict_batch_begin(step)
# --> 559     data = get_data(iterator)
#     560     batch_outputs = self.predict_function(data)
#     561     outputs = append_to_outputs(batch_outputs, outputs)
#
# File ~\anaconda3\envs\smartenv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:539, in TensorFlowTrainer.predict.<locals>.get_data(iterator)
#     537 for _ in range(self.steps_per_execution):
#     538     try:
# --> 539         single_step_data = next(iterator)
#     540     except (StopIteration, tf.errors.OutOfRangeError) as e:
#     541         if hasattr(data, "__len__") and len(data) > 0:
#     542             # Suppress the error when still have remaining data.
#
# File ~\anaconda3\envs\smartenv\Lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:826, in OwnedIterator.__next__(self)
#     824 def __next__(self):
#     825   try:
# --> 826     return self._next_internal()
#     827   except errors.OutOfRangeError:
#     828     raise StopIteration
#
# File ~\anaconda3\envs\smartenv\Lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:776, in OwnedIterator._next_internal(self)
#     773 # TODO(b/77291417): This runs in sync mode as iterators use an error status
#     774 # to communicate that there is no more data to iterate over.
#     775 with context.execution_mode(context.SYNC):
# --> 776   ret = gen_dataset_ops.iterator_get_next(
#     777       self._iterator_resource,
#     778       output_types=self._flat_output_types,
#     779       output_shapes=self._flat_output_shapes)
#     781   try:
#     782     # Fast path for the case `self._structure` is not a nested structure.
#     783     return self._element_spec._from_compatible_tensor_list(ret)  # pylint: disable=protected-access
#
# File ~\anaconda3\envs\smartenv\Lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py:3081, in iterator_get_next(iterator, output_types, output_shapes, name)
#    3079 if tld.is_eager:
#    3080   try:
# -> 3081     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3082       _ctx, "IteratorGetNext", name, iterator, "output_types", output_types,
#    3083       "output_shapes", output_shapes)
#    3084     return _result
#    3085   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
